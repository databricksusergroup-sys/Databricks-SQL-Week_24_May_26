# %% [markdown]
# ## Dataset Reference for Day 2 Practice
#
# The following table will be used throughout to practice SQL queries and filtering techniques in Databricks SQL.
#
# Students will use this table to perform:
#
# - SELECT queries
# - Filtering using WHERE
# - Sorting using ORDER BY
# - Pattern matching using LIKE and RLIKE
# - NULL handling
# - DISTINCT operations
# - LIMIT and OFFSET
# - Type casting using CAST()
# - Alias creation
# - Conditional filtering using AND, OR, IN, and BETWEEN
#
# This table is designed to simulate a real-world e-commerce category dataset and helps students understand how SQL is used in practical industry scenarios.
#
# ---
#
# ##    Categories Table
# | Field Name  | Data Type | Description                |
# | ----------- | --------- | -------------------------- |
# | id          | STRING    | Unique category ID         |
# | name        | STRING    | Category name              |
# | slug        | STRING    | URL-friendly category name |
# | description | STRING    | Category description       |
# | parent_id   | STRING    | Parent category ID         |
# | created_at  | TIMESTAMP | Creation timestamp         |
# | updated_at  | TIMESTAMP | Last updated timestamp     |

# %%
# %sql 
USE workspace.ecommerce_sql

# %% [markdown]
# # Beginner Level Questions

# %%
# Question: Create a student table with columns id (STRING), name (STRING), age (INT), and enrollment_date (DATE).

# %%
# Question: Write a SQL statement to create a student table with columns id (STRING, NOT NULL, PRIMARY KEY), name (STRING, NOT NULL), age (INT), and enrollment_date (DATE). Ensure appropriate constraints are applied.

# %%
# Insert into with column name

# %%
# Insert into without column name

# %%
# Insert into with column name With multiple rows

# %%
# %sql
-- Question 1: Display all columns from the categories table.

# %%
# %sql
-- Question 2: Display only id and name columns.

# %%
# %sql
-- Question 3: Display the name column with alias category_name.

# %%
# %sql
-- Question 4: Display the slug column with alias category_slug.

# %%
# %sql
-- Question 5: Display all unique parent_id values.

# %%
# %sql
-- Question 6: Display all categories where name is 'Electronics'.

# %%
# %sql
-- Question 7: Display all categories where parent_id is NULL.

# %%
# %sql
-- Question 8: Display all categories where parent_id is NOT NULL.

# %%
# %sql
-- Question 9: Display all categories where name starts with 'M'.

# %%
# %sql
-- Question 10: Display all categories where name ends with 's'.

# %%
# %sql
-- Question 11: Display all categories where slug contains the word 'phone'.

# %%
# %sql
-- Question 12: Display only the first 3 rows from the table.

# %%
# %sql
-- Question 13: Sort all categories by name in ascending order.

# %%
# %sql
-- Question 14: Sort all categories by name in descending order.

# %%
# %sql
-- Question 15: Display only id, name, and slug columns.

# %% [markdown]
# # Intermediate Level Questions

# %%
# %sql
-- Question 16: Display all categories where name contains exactly 5 characters.

# %%
# %sql
-- Question 17: Display all categories where name matches the pattern 'Home%'.

# %%
# %sql
-- Question 18: Display all categories where slug matches a regex pattern.

# %%
# %sql
-- Question 19: Display all categories where name is either 'Electronics', 'Books', or 'Fashion'.

# %%
# %sql
-- Question 20: Display all categories where name is NOT 'Electronics'.

# %%
# %sql
-- Question 21: Display all categories where parent_id is NOT NULL and name starts with 'S'.

# %%
# %sql
-- Question 22: Display all categories where name starts with 'B' OR slug contains 'tech'.

# %%
# %sql
-- Question 23: Display all categories created after '2025-01-01'.

# %%
# %sql
-- Question 24: Display all categories created between '2025-01-01' and '2025-12-31'.

# %%
# %sql
-- Question 25: Sort categories by parent_id using NULLS FIRST.

# %%
# %sql
-- Question 26: Sort categories by parent_id using NULLS LAST.

# %%
# %sql
-- Question 27: Sort categories first by name and then by created_at.

# %%
# %sql
-- Question 28: Display 2 rows after skipping the first 1 row.

# %% [markdown]
# # Advanced Level Questions

# %%
# %sql
-- Question 29: Convert the id column into STRING datatype.

# %%
# %sql
-- Question 30: Try converting the id column using safe casting.

# %%
# %sql
-- Question 31: Create a computed column by combining name and slug.

# %%
# %sql
-- Question 32: Display category names in uppercase.

# %%
# %sql
-- Question 33: Display category names in lowercase.

# %%
# %sql
-- Question 34: Find the length of each category name.

# %%
# %sql
-- Question 35: Replace the word 'Sports' with 'Running' in description.

# %%
# %sql
-- Question 36: Display the current date.

# %%
# %sql
-- Question 37: Display the current timestamp.

# %%
# %sql
-- Question 38: Display categories where description contains the word 'devices'.

# %%
# %sql
-- Question 39: Display categories where slug starts with 'mobile'.

# %%
# %sql
-- Question 40: Display the latest 3 updated categories.
