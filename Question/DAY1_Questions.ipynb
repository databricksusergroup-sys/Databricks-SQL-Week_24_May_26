# %% [markdown]
# # Databricks SQL — Day 1 Practice Questions

# %% [markdown]
# ## Question 1
#
# What is data? Explain the different types of data with examples.

# %% [markdown]
# ## Question 2
#
# What is a database? Why are databases important in modern systems?

# %% [markdown]
# ## Question 3
#
# What is DBMS? Explain its main responsibilities with examples.

# %% [markdown]
# ## Question 4
#
# Differentiate between:
# - Structured Data
# - Semi-Structured Data
# - Unstructured Data

# %% [markdown]
# ## Question 5
#
# What is a Data Warehouse? Explain its features and use cases.

# %% [markdown]
# ## Question 6
#
# What is a Data Lake? Explain its features and advantages.

# %% [markdown]
# ## Question 7
#
# Differentiate between a Data Warehouse and a Data Lake.

# %% [markdown]
# ## Question 8
#
# Explain OLTP and OLAP systems. Compare them with suitable examples.

# %% [markdown]
# ## Question 9
#
# What is Databricks SQL? Explain the main components of the Databricks SQL workspace.

# %% [markdown]
# ## Question 10
#
# Explain the Databricks namespace structure:
#
# ```text
# catalog.schema.table
# ```
#
# Also explain:
# - Catalog
# - Schema
# - Table

# %% [markdown]
# ## Question 11
#
# What is SQL? Explain the different categories of SQL commands with examples.

# %% [markdown]
# ## Question 12
#
# Explain briefly:
# - Primary Key
# - Foreign Key
# - Candidate Key
# - Composite Key
# - Unique Key
