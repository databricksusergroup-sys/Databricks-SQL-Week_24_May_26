-- %% [markdown]
-- # Databricks SQL Week
--
-- ## Workshop Setup Script
--
-- **Dataset:** E-Commerce Analytics
--
-- ---
--
-- ### Purpose
--
-- 1. **Create catalog and schema safely**
-- 2. **Create workshop tables**
-- 3. **Load reusable demo data**
-- 4. **Create analytical views**
-- 5. **Validate setup**
-- 6. **Provide cleanup scripts**
--
-- ---

-- %% [markdown]
-- ## CREATE CATALOG & SCHEMA

-- %%
%sql
-- Create catalog
CREATE CATALOG IF NOT EXISTS workspace;

-- %%
%sql
-- Switch to catalog
USE CATALOG workspace;

-- %%
%sql
-- Create schema safely
CREATE SCHEMA IF NOT EXISTS ecommerce_sql;

-- %%
%sql
-- Switch to schema
USE SCHEMA ecommerce_sql;

-- %% [markdown]
-- ## CREATE TABLES

-- %%
%sql
-- =========================================================
-- TABLE: categories
-- =========================================================
CREATE TABLE IF NOT EXISTS categories (
    id STRING,
    name STRING NOT NULL,
    slug STRING NOT NULL,
    description STRING,
    parent_id STRING,
    created_at TIMESTAMP,
    updated_at TIMESTAMP
);

-- %%
%sql
-- =========================================================
-- TABLE: users
-- Stores customers and administrators
-- =========================================================

CREATE TABLE IF NOT EXISTS users (
    id STRING,
    email STRING NOT NULL,
    password_hash STRING NOT NULL,
    first_name STRING NOT NULL,
    last_name STRING NOT NULL,
    role STRING,
    phone STRING,
    created_at TIMESTAMP,
    updated_at TIMESTAMP
);

-- %%
-- =========================================================
-- TABLE: products
-- Stores product catalog
-- =========================================================

CREATE TABLE IF NOT EXISTS products (
    id STRING,
    category_id STRING,
    name STRING NOT NULL,
    slug STRING NOT NULL,
    description STRING,
    price DECIMAL(10,2),
    sku STRING,
    is_active BOOLEAN,
    created_at TIMESTAMP,
    updated_at TIMESTAMP
);

-- %%
-- =========================================================
-- TABLE: inventory
-- Stores stock tracking information
-- =========================================================

CREATE TABLE IF NOT EXISTS inventory (
    id STRING,
    product_id STRING,
    quantity INT,
    reorder_level INT,
    updated_at TIMESTAMP
);

-- %%
-- =========================================================
-- TABLE: orders
-- Stores customer orders
-- =========================================================

CREATE TABLE IF NOT EXISTS orders (
    id STRING,
    user_id STRING,
    product_id STRING,
    quantity INT,
    unit_price DECIMAL(10,2),
    total_amount DECIMAL(12,2),
    status STRING,
    shipping_address STRING,
    billing_address STRING,
    created_at TIMESTAMP,
    updated_at TIMESTAMP
);

-- %% [markdown]
-- ## Insert Into Tables

-- %%
INSERT OVERWRITE categories VALUES
('1001', 'Electronics', 'electronics', 'Computers and electronic gadgets', NULL, current_timestamp(), current_timestamp()),
('1002', 'Laptops', 'laptops', 'High performance laptops and notebooks', '1001', current_timestamp(), current_timestamp()),
('1003', 'Smartphones', 'smartphones', 'Latest smartphones and accessories', '1001', current_timestamp(), current_timestamp()),
('1004', 'Tablets', 'tablets', 'Android and iOS tablets', '1001', current_timestamp(), current_timestamp()),

('1005', 'Books', 'books', 'Books and learning materials', NULL, current_timestamp(), current_timestamp()),
('1006', 'Fiction', 'fiction', 'Novels and fictional books', '1005', current_timestamp(), current_timestamp()),
('1007', 'Educational', 'educational', 'Academic and educational books', '1005', current_timestamp(), current_timestamp()),

('1008', 'Clothing', 'clothing', 'Fashion and apparel', NULL, current_timestamp(), current_timestamp()),
('1009', 'Men Clothing', 'men-clothing', 'Fashion apparel for men', '1008', current_timestamp(), current_timestamp()),
('1010', 'Women Clothing', 'women-clothing', 'Fashion apparel for women', '1008', current_timestamp(), current_timestamp()),

('1011', 'Home & Kitchen', 'home-kitchen', 'Home appliances and kitchen essentials', NULL, current_timestamp(), current_timestamp()),
('1012', 'Furniture', 'furniture', 'Home and office furniture', '1011', current_timestamp(), current_timestamp()),

('1013', 'Sports', 'sports', 'Sports equipment and accessories', NULL, current_timestamp(), current_timestamp()),
('1014', 'Fitness', 'fitness', 'Gym and fitness products', '1013', current_timestamp(), current_timestamp()),

('1015', 'Beauty', 'beauty', 'Beauty and personal care products', NULL, current_timestamp(), current_timestamp()),
('1016', 'Toys', 'toys', 'Kids toys and games', NULL, current_timestamp(), current_timestamp()),
('1017', 'Automotive', 'automotive', 'Vehicle accessories and tools', NULL, current_timestamp(), current_timestamp()),
('1018', 'Groceries', 'groceries', 'Daily grocery and food items', NULL, current_timestamp(), current_timestamp());

-- %%
INSERT OVERWRITE users VALUES
('2001', 'aarav.sharma@example.in', 'hashed_password_1', 'Aarav', 'Sharma', 'admin', '+91-9876501001', current_timestamp(), current_timestamp()),
('2002', 'vivaan.verma@example.in', 'hashed_password_2', 'Vivaan', 'Verma', 'customer', '+91-9876501002', current_timestamp(), current_timestamp()),
('2003', 'aditya.singh@example.in', 'hashed_password_3', 'Aditya', 'Singh', 'customer', '+91-9876501003', current_timestamp(), current_timestamp()),
('2004', 'krishna.patel@example.in', 'hashed_password_4', 'Krishna', 'Patel', 'customer', '+91-9876501004', current_timestamp(), current_timestamp()),
('2005', 'arjun.mehra@example.in', 'hashed_password_5', 'Arjun', 'Mehra', 'customer', '+91-9876501005', current_timestamp(), current_timestamp()),
('2006', 'isha.gupta@example.in', 'hashed_password_6', 'Isha', 'Gupta', 'customer', '+91-9876501006', current_timestamp(), current_timestamp()),
('2007', 'ananya.reddy@example.in', 'hashed_password_7', 'Ananya', 'Reddy', 'customer', '+91-9876501007', current_timestamp(), current_timestamp()),
('2008', 'diya.nair@example.in', 'hashed_password_8', 'Diya', 'Nair', 'customer', '+91-9876501008', current_timestamp(), current_timestamp()),
('2009', 'riya.kapoor@example.in', 'hashed_password_9', 'Riya', 'Kapoor', 'customer', '+91-9876501009', current_timestamp(), current_timestamp()),
('2010', 'saanvi.joshi@example.in', 'hashed_password_10', 'Saanvi', 'Joshi', 'customer', '+91-9876501010', current_timestamp(), current_timestamp()),

('2011', 'rahul.yadav@example.in', 'hashed_password_11', 'Rahul', 'Yadav', 'customer', '+91-9876501011', current_timestamp(), current_timestamp()),
('2012', 'rohan.malhotra@example.in', 'hashed_password_12', 'Rohan', 'Malhotra', 'customer', '+91-9876501012', current_timestamp(), current_timestamp()),
('2013', 'karan.bansal@example.in', 'hashed_password_13', 'Karan', 'Bansal', 'customer', '+91-9876501013', current_timestamp(), current_timestamp()),
('2014', 'neha.saxena@example.in', 'hashed_password_14', 'Neha', 'Saxena', 'customer', '+91-9876501014', current_timestamp(), current_timestamp()),
('2015', 'pooja.chopra@example.in', 'hashed_password_15', 'Pooja', 'Chopra', 'customer', '+91-9876501015', current_timestamp(), current_timestamp()),
('2016', 'simran.arora@example.in', 'hashed_password_16', 'Simran', 'Arora', 'customer', '+91-9876501016', current_timestamp(), current_timestamp()),
('2017', 'manav.agarwal@example.in', 'hashed_password_17', 'Manav', 'Agarwal', 'customer', '+91-9876501017', current_timestamp(), current_timestamp()),
('2018', 'tanya.sethi@example.in', 'hashed_password_18', 'Tanya', 'Sethi', 'customer', '+91-9876501018', current_timestamp(), current_timestamp()),
('2019', 'nidhi.khanna@example.in', 'hashed_password_19', 'Nidhi', 'Khanna', 'customer', '+91-9876501019', current_timestamp(), current_timestamp()),
('2020', 'akash.rana@example.in', 'hashed_password_20', 'Akash', 'Rana', 'customer', '+91-9876501020', current_timestamp(), current_timestamp()),

('2021', 'mohit.tyagi@example.in', 'hashed_password_21', 'Mohit', 'Tyagi', 'customer', '+91-9876501021', current_timestamp(), current_timestamp()),
('2022', 'priya.mishra@example.in', 'hashed_password_22', 'Priya', 'Mishra', 'customer', '+91-9876501022', current_timestamp(), current_timestamp()),
('2023', 'harsh.vardhan@example.in', 'hashed_password_23', 'Harsh', 'Vardhan', 'customer', '+91-9876501023', current_timestamp(), current_timestamp()),
('2024', 'kavya.iyer@example.in', 'hashed_password_24', 'Kavya', 'Iyer', 'customer', '+91-9876501024', current_timestamp(), current_timestamp()),
('2025', 'vishal.chauhan@example.in', 'hashed_password_25', 'Vishal', 'Chauhan', 'customer', '+91-9876501025', current_timestamp(), current_timestamp()),
('2026', 'deepak.kumar@example.in', 'hashed_password_26', 'Deepak', 'Kumar', 'customer', '+91-9876501026', current_timestamp(), current_timestamp()),
('2027', 'megha.rastogi@example.in', 'hashed_password_27', 'Megha', 'Rastogi', 'customer', '+91-9876501027', current_timestamp(), current_timestamp()),
('2028', 'ankit.srivastava@example.in', 'hashed_password_28', 'Ankit', 'Srivastava', 'customer', '+91-9876501028', current_timestamp(), current_timestamp()),
('2029', 'shruti.pandey@example.in', 'hashed_password_29', 'Shruti', 'Pandey', 'customer', '+91-9876501029', current_timestamp(), current_timestamp()),
('2030', 'yash.thakur@example.in', 'hashed_password_30', 'Yash', 'Thakur', 'customer', '+91-9876501030', current_timestamp(), current_timestamp()),

('2031', 'abhishek.dubey@example.in', 'hashed_password_31', 'Abhishek', 'Dubey', 'customer', '+91-9876501031', current_timestamp(), current_timestamp()),
('2032', 'sakshi.bhardwaj@example.in', 'hashed_password_32', 'Sakshi', 'Bhardwaj', 'customer', '+91-9876501032', current_timestamp(), current_timestamp()),
('2033', 'aman.tiwari@example.in', 'hashed_password_33', 'Aman', 'Tiwari', 'customer', '+91-9876501033', current_timestamp(), current_timestamp()),
('2034', 'payal.soni@example.in', 'hashed_password_34', 'Payal', 'Soni', 'customer', '+91-9876501034', current_timestamp(), current_timestamp()),
('2035', 'chetan.jain@example.in', 'hashed_password_35', 'Chetan', 'Jain', 'customer', '+91-9876501035', current_timestamp(), current_timestamp()),
('2036', 'nikita.ahuja@example.in', 'hashed_password_36', 'Nikita', 'Ahuja', 'customer', '+91-9876501036', current_timestamp(), current_timestamp()),
('2037', 'siddharth.rawat@example.in', 'hashed_password_37', 'Siddharth', 'Rawat', 'customer', '+91-9876501037', current_timestamp(), current_timestamp()),
('2038', 'muskan.goyal@example.in', 'hashed_password_38', 'Muskan', 'Goyal', 'customer', '+91-9876501038', current_timestamp(), current_timestamp()),
('2039', 'varun.bhatt@example.in', 'hashed_password_39', 'Varun', 'Bhatt', 'customer', '+91-9876501039', current_timestamp(), current_timestamp()),
('2040', 'rashmi.desai@example.in', 'hashed_password_40', 'Rashmi', 'Desai', 'customer', '+91-9876501040', current_timestamp(), current_timestamp()),

('2041', 'gaurav.purohit@example.in', 'hashed_password_41', 'Gaurav', 'Purohit', 'customer', '+91-9876501041', current_timestamp(), current_timestamp()),
('2042', 'sonal.menon@example.in', 'hashed_password_42', 'Sonal', 'Menon', 'customer', '+91-9876501042', current_timestamp(), current_timestamp()),
('2043', 'rakesh.shetty@example.in', 'hashed_password_43', 'Rakesh', 'Shetty', 'customer', '+91-9876501043', current_timestamp(), current_timestamp()),
('2044', 'bhavna.luthra@example.in', 'hashed_password_44', 'Bhavna', 'Luthra', 'customer', '+91-9876501044', current_timestamp(), current_timestamp()),
('2045', 'dev.mukherjee@example.in', 'hashed_password_45', 'Dev', 'Mukherjee', 'customer', '+91-9876501045', current_timestamp(), current_timestamp()),
('2046', 'tanvi.pillai@example.in', 'hashed_password_46', 'Tanvi', 'Pillai', 'customer', '+91-9876501046', current_timestamp(), current_timestamp()),
('2047', 'rajat.kohli@example.in', 'hashed_password_47', 'Rajat', 'Kohli', 'customer', '+91-9876501047', current_timestamp(), current_timestamp()),
('2048', 'keerthi.naidu@example.in', 'hashed_password_48', 'Keerthi', 'Naidu', 'customer', '+91-9876501048', current_timestamp(), current_timestamp()),
('2049', 'alok.saxena@example.in', 'hashed_password_49', 'Alok', 'Saxena', 'customer', '+91-9876501049', current_timestamp(), current_timestamp()),
('2050', 'preeti.sharma@example.in', 'hashed_password_50', 'Preeti', 'Sharma', 'customer', '+91-9876501050', current_timestamp(), current_timestamp()),

('2051', 'naveen.chandra@example.in', 'hashed_password_51', 'Naveen', 'Chandra', 'customer', '+91-9876501051', current_timestamp(), current_timestamp()),
('2052', 'aarti.bajaj@example.in', 'hashed_password_52', 'Aarti', 'Bajaj', 'customer', '+91-9876501052', current_timestamp(), current_timestamp()),
('2053', 'vivek.singhal@example.in', 'hashed_password_53', 'Vivek', 'Singhal', 'customer', '+91-9876501053', current_timestamp(), current_timestamp()),
('2054', 'shreya.das@example.in', 'hashed_password_54', 'Shreya', 'Das', 'customer', '+91-9876501054', current_timestamp(), current_timestamp()),
('2055', 'kunal.rajput@example.in', 'hashed_password_55', 'Kunal', 'Rajput', 'customer', '+91-9876501055', current_timestamp(), current_timestamp());

-- %%
INSERT OVERWRITE products VALUES
('3001', '1002', 'Lenovo IdeaPad Slim 5', 'lenovo-ideapad-slim-5', '16GB RAM Ryzen 7 laptop', 68999.00, 'LAP-LEN-001', true, current_timestamp(), current_timestamp()),
('3002', '1002', 'HP Pavilion x360', 'hp-pavilion-x360', 'Touchscreen Intel i5 laptop', 72999.00, 'LAP-HP-002', true, current_timestamp(), current_timestamp()),
('3003', '1002', 'ASUS ROG Strix G16', 'asus-rog-strix-g16', 'Gaming laptop RTX 4060', 124999.00, 'LAP-ASUS-003', true, current_timestamp(), current_timestamp()),
('3004', '1002', 'Dell Inspiron 15', 'dell-inspiron-15', 'Everyday productivity laptop', 55999.00, 'LAP-DEL-004', true, current_timestamp(), current_timestamp()),
('3005', '1002', 'Acer Aspire 7', 'acer-aspire-7', 'Gaming and office laptop', 61999.00, 'LAP-ACE-005', true, current_timestamp(), current_timestamp()),
('3006', '1002', 'MacBook Air M2', 'macbook-air-m2', 'Apple lightweight laptop', 99999.00, 'LAP-APL-006', true, current_timestamp(), current_timestamp()),
('3007', '1002', 'MSI Katana GF66', 'msi-katana-gf66', 'Gaming laptop i7 RTX', 114999.00, 'LAP-MSI-007', true, current_timestamp(), current_timestamp()),
('3008', '1002', 'Samsung Galaxy Book4', 'samsung-galaxy-book4', 'Thin and light laptop', 67999.00, 'LAP-SAM-008', true, current_timestamp(), current_timestamp()),
('3009', '1002', 'Realme Book Prime', 'realme-book-prime', 'Metal body ultrabook', 52999.00, 'LAP-RLM-009', true, current_timestamp(), current_timestamp()),
('3010', '1002', 'Infinix INBook X2', 'infinix-inbook-x2', 'Affordable student laptop', 34999.00, 'LAP-INF-010', true, current_timestamp(), current_timestamp()),

('3011', '1003', 'iPhone 15', 'iphone-15', 'Apple smartphone 128GB', 79999.00, 'PHN-APL-011', true, current_timestamp(), current_timestamp()),
('3012', '1003', 'Samsung Galaxy S25', 'samsung-galaxy-s25', 'Flagship Android smartphone', 84999.00, 'PHN-SAM-012', true, current_timestamp(), current_timestamp()),
('3013', '1003', 'OnePlus 13R', 'oneplus-13r', 'Premium Android smartphone', 45999.00, 'PHN-ONE-013', true, current_timestamp(), current_timestamp()),
('3014', '1003', 'Nothing Phone 3', 'nothing-phone-3', 'Transparent design smartphone', 42999.00, 'PHN-NTH-014', true, current_timestamp(), current_timestamp()),
('3015', '1003', 'Redmi Note 14 Pro', 'redmi-note-14-pro', 'Affordable 5G smartphone', 21999.00, 'PHN-RDM-015', true, current_timestamp(), current_timestamp()),
('3016', '1003', 'Realme GT Neo', 'realme-gt-neo', 'Gaming smartphone', 28999.00, 'PHN-RLM-016', true, current_timestamp(), current_timestamp()),
('3017', '1003', 'Vivo V40 Pro', 'vivo-v40-pro', 'Camera centric smartphone', 37999.00, 'PHN-VIV-017', true, current_timestamp(), current_timestamp()),
('3018', '1003', 'Oppo Reno 12', 'oppo-reno-12', 'Stylish Android smartphone', 32999.00, 'PHN-OPP-018', true, current_timestamp(), current_timestamp()),
('3019', '1003', 'Moto Edge 60', 'moto-edge-60', 'Near stock Android phone', 34999.00, 'PHN-MOT-019', true, current_timestamp(), current_timestamp()),
('3020', '1003', 'Poco X7 Pro', 'poco-x7-pro', 'Performance focused smartphone', 26999.00, 'PHN-POC-020', true, current_timestamp(), current_timestamp()),

('3021', '1001', 'Boat Rockerz 550', 'boat-rockerz-550', 'Wireless headphones', 2499.00, 'ELC-BOAT-021', true, current_timestamp(), current_timestamp()),
('3022', '1001', 'JBL Flip 6', 'jbl-flip-6', 'Bluetooth speaker', 8999.00, 'ELC-JBL-022', true, current_timestamp(), current_timestamp()),
('3023', '1001', 'Sony WH-1000XM5', 'sony-wh1000xm5', 'Noise cancelling headphones', 27999.00, 'ELC-SNY-023', true, current_timestamp(), current_timestamp()),
('3024', '1001', 'Logitech MX Master 3S', 'logitech-mx-master-3s', 'Wireless productivity mouse', 8995.00, 'ELC-LOG-024', true, current_timestamp(), current_timestamp()),
('3025', '1001', 'Portronics USB Hub', 'portronics-usb-hub', '4 port USB hub', 899.00, 'ELC-POR-025', true, current_timestamp(), current_timestamp()),
('3026', '1001', 'Mi Power Bank 20000mAh', 'mi-power-bank-20000mah', 'Fast charging power bank', 1999.00, 'ELC-MI-026', true, current_timestamp(), current_timestamp()),
('3027', '1001', 'Ambrane Charger 65W', 'ambrane-charger-65w', 'Fast charging adapter', 1499.00, 'ELC-AMB-027', true, current_timestamp(), current_timestamp()),
('3028', '1001', 'Noise Smartwatch ColorFit', 'noise-smartwatch-colorfit', 'Fitness smartwatch', 2999.00, 'ELC-NOI-028', true, current_timestamp(), current_timestamp()),
('3029', '1001', 'FireBoltt Ninja Call Pro', 'fireboltt-ninja-call-pro', 'Bluetooth calling smartwatch', 1799.00, 'ELC-FBT-029', true, current_timestamp(), current_timestamp()),
('3030', '1001', 'SanDisk 128GB Pendrive', 'sandisk-128gb-pendrive', 'USB 3.0 storage device', 899.00, 'ELC-SND-030', true, current_timestamp(), current_timestamp()),

('3031', '1007', 'Atomic Habits', 'atomic-habits', 'Self improvement bestseller', 499.00, 'BOK-ATM-031', true, current_timestamp(), current_timestamp()),
('3032', '1007', 'Rich Dad Poor Dad', 'rich-dad-poor-dad', 'Personal finance book', 399.00, 'BOK-RDPD-032', true, current_timestamp(), current_timestamp()),
('3033', '1007', 'Deep Work', 'deep-work', 'Productivity and focus guide', 599.00, 'BOK-DPW-033', true, current_timestamp(), current_timestamp()),
('3034', '1007', 'The Psychology of Money', 'psychology-of-money', 'Money mindset book', 449.00, 'BOK-PSY-034', true, current_timestamp(), current_timestamp()),
('3035', '1007', 'Mastering Databricks SQL', 'mastering-databricks-sql', 'SQL analytics handbook', 799.00, 'BOK-DBR-035', true, current_timestamp(), current_timestamp()),
('3036', '1007', 'Operating Systems Concepts', 'operating-systems-concepts', 'Computer science textbook', 899.00, 'BOK-OSC-036', true, current_timestamp(), current_timestamp()),
('3037', '1007', 'Data Structures in Java', 'data-structures-java', 'DSA programming guide', 699.00, 'BOK-DSJ-037', true, current_timestamp(), current_timestamp()),
('3038', '1007', 'Wings of Fire', 'wings-of-fire', 'Biography of APJ Abdul Kalam', 299.00, 'BOK-WOF-038', true, current_timestamp(), current_timestamp()),
('3039', '1007', 'Ikigai', 'ikigai', 'Japanese philosophy book', 399.00, 'BOK-IKI-039', true, current_timestamp(), current_timestamp()),
('3040', '1007', 'Think and Grow Rich', 'think-and-grow-rich', 'Success mindset book', 349.00, 'BOK-TGR-040', true, current_timestamp(), current_timestamp()),

('3041', '1009', 'Allen Solly Men Shirt', 'allen-solly-men-shirt', 'Slim fit formal shirt', 1799.00, 'MEN-ALS-041', true, current_timestamp(), current_timestamp()),
('3042', '1009', 'Levis 511 Jeans', 'levis-511-jeans', 'Slim fit denim jeans', 2499.00, 'MEN-LVS-042', true, current_timestamp(), current_timestamp()),
('3043', '1009', 'Nike Running T-Shirt', 'nike-running-tshirt', 'Breathable sports tee', 1499.00, 'MEN-NKE-043', true, current_timestamp(), current_timestamp()),
('3044', '1009', 'Puma Sports Shoes', 'puma-sports-shoes', 'Running shoes for men', 3299.00, 'MEN-PUM-044', true, current_timestamp(), current_timestamp()),
('3045', '1009', 'Roadster Casual Hoodie', 'roadster-casual-hoodie', 'Winter hoodie for men', 1599.00, 'MEN-RDS-045', true, current_timestamp(), current_timestamp()),
('3046', '1010', 'Biba Kurta Set', 'biba-kurta-set', 'Printed ethnic wear set', 2999.00, 'WMN-BIB-046', true, current_timestamp(), current_timestamp()),
('3047', '1010', 'Womens Palazzo Pants', 'womens-palazzo-pants', 'Comfortable rayon palazzo', 899.00, 'WMN-PLZ-047', true, current_timestamp(), current_timestamp()),
('3048', '1010', 'Zara Floral Dress', 'zara-floral-dress', 'Casual floral summer dress', 3599.00, 'WMN-ZAR-048', true, current_timestamp(), current_timestamp()),
('3049', '1010', 'Libas Anarkali Kurti', 'libas-anarkali-kurti', 'Festive ethnic kurti', 1899.00, 'WMN-LBS-049', true, current_timestamp(), current_timestamp()),
('3050', '1010', 'H&M Women Top', 'hm-women-top', 'Casual cotton top', 1299.00, 'WMN-HM-050', true, current_timestamp(), current_timestamp()),

('3051', '1011', 'Prestige Pressure Cooker', 'prestige-pressure-cooker', '5 litre pressure cooker', 2199.00, 'HM-PRS-051', true, current_timestamp(), current_timestamp()),
('3052', '1011', 'Philips Air Fryer', 'philips-air-fryer', 'Healthy oil free cooking', 8499.00, 'HM-PHL-052', true, current_timestamp(), current_timestamp()),
('3053', '1011', 'Pigeon Non Stick Pan', 'pigeon-non-stick-pan', 'Induction compatible pan', 799.00, 'HM-PGN-053', true, current_timestamp(), current_timestamp()),
('3054', '1011', 'Havells Mixer Grinder', 'havells-mixer-grinder', '750W kitchen mixer', 4499.00, 'HM-HAV-054', true, current_timestamp(), current_timestamp()),
('3055', '1011', 'Milton Water Bottle', 'milton-water-bottle', '1 litre steel bottle', 599.00, 'HM-MLT-055', true, current_timestamp(), current_timestamp()),
('3056', '1012', 'Nilkamal Office Chair', 'nilkamal-office-chair', 'Ergonomic mesh chair', 5499.00, 'FUR-NIL-056', true, current_timestamp(), current_timestamp()),
('3057', '1012', 'Wooden Study Table', 'wooden-study-table', 'Engineered wood desk', 6999.00, 'FUR-WOD-057', true, current_timestamp(), current_timestamp()),
('3058', '1012', 'Urban Ladder Sofa', 'urban-ladder-sofa', '3 seater fabric sofa', 24999.00, 'FUR-URL-058', true, current_timestamp(), current_timestamp()),
('3059', '1012', 'Bookshelf Rack', 'bookshelf-rack', 'Wooden storage shelf', 3999.00, 'FUR-BSH-059', true, current_timestamp(), current_timestamp()),
('3060', '1012', 'Bean Bag XXL', 'bean-bag-xxl', 'Comfortable lounger bean bag', 2499.00, 'FUR-BBG-060', true, current_timestamp(), current_timestamp()),

('3061', '1013', 'SG Cricket Bat', 'sg-cricket-bat', 'English willow cricket bat', 4999.00, 'SPT-SG-061', true, current_timestamp(), current_timestamp()),
('3062', '1013', 'Cosco Football', 'cosco-football', 'Training football size 5', 899.00, 'SPT-COS-062', true, current_timestamp(), current_timestamp()),
('3063', '1013', 'Yonex Badminton Racquet', 'yonex-badminton-racquet', 'Lightweight badminton racquet', 1999.00, 'SPT-YON-063', true, current_timestamp(), current_timestamp()),
('3064', '1014', 'Cult Dumbbell Set', 'cult-dumbbell-set', 'Adjustable gym dumbbells', 3499.00, 'FIT-CLT-064', true, current_timestamp(), current_timestamp()),
('3065', '1014', 'Yoga Mat 6mm', 'yoga-mat-6mm', 'Anti slip yoga mat', 899.00, 'FIT-YOG-065', true, current_timestamp(), current_timestamp()),
('3066', '1014', 'Resistance Bands Set', 'resistance-bands-set', 'Workout resistance bands', 699.00, 'FIT-RBS-066', true, current_timestamp(), current_timestamp()),
('3067', '1014', 'Treadmill Foldable', 'treadmill-foldable', 'Home cardio treadmill', 28999.00, 'FIT-TRD-067', true, current_timestamp(), current_timestamp()),
('3068', '1014', 'Protein Shaker Bottle', 'protein-shaker-bottle', 'Gym shaker 700ml', 399.00, 'FIT-SHK-068', true, current_timestamp(), current_timestamp()),
('3069', '1015', 'Lakme Face Wash', 'lakme-face-wash', 'Daily glow face wash', 299.00, 'BEA-LAK-069', true, current_timestamp(), current_timestamp()),
('3070', '1015', 'Mamaearth Onion Shampoo', 'mamaearth-onion-shampoo', 'Hair fall control shampoo', 449.00, 'BEA-MAM-070', true, current_timestamp(), current_timestamp()),

('3071', '1015', 'Maybelline Lipstick', 'maybelline-lipstick', 'Matte finish lipstick', 599.00, 'BEA-MAY-071', true, current_timestamp(), current_timestamp()),
('3072', '1015', 'Nivea Body Lotion', 'nivea-body-lotion', 'Moisturizing lotion', 349.00, 'BEA-NIV-072', true, current_timestamp(), current_timestamp()),
('3073', '1015', 'Cetaphil Cleanser', 'cetaphil-cleanser', 'Gentle skin cleanser', 799.00, 'BEA-CET-073', true, current_timestamp(), current_timestamp()),
('3074', '1016', 'Remote Control Car', 'remote-control-car', 'Rechargeable RC toy car', 1299.00, 'TOY-RCC-074', true, current_timestamp(), current_timestamp()),
('3075', '1016', 'LEGO Classic Box', 'lego-classic-box', 'Creative building blocks', 2499.00, 'TOY-LEG-075', true, current_timestamp(), current_timestamp()),
('3076', '1016', 'Barbie Dream House', 'barbie-dream-house', 'Kids doll house set', 5999.00, 'TOY-BAR-076', true, current_timestamp(), current_timestamp()),
('3077', '1016', 'Hot Wheels Pack', 'hot-wheels-pack', 'Mini racing cars set', 799.00, 'TOY-HOT-077', true, current_timestamp(), current_timestamp()),
('3078', '1017', 'Michelin Bike Helmet', 'michelin-bike-helmet', 'Protective riding helmet', 1999.00, 'AUT-MIC-078', true, current_timestamp(), current_timestamp()),
('3079', '1017', 'Car Vacuum Cleaner', 'car-vacuum-cleaner', 'Portable car cleaning device', 1499.00, 'AUT-CVC-079', true, current_timestamp(), current_timestamp()),
('3080', '1017', 'Tyre Inflator Pump', 'tyre-inflator-pump', 'Portable air compressor', 2499.00, 'AUT-TYR-080', true, current_timestamp(), current_timestamp()),

('3081', '1018', 'Aashirvaad Atta 10kg', 'aashirvaad-atta-10kg', 'Whole wheat flour pack', 499.00, 'GRC-AAT-081', true, current_timestamp(), current_timestamp()),
('3082', '1018', 'Tata Salt 1kg', 'tata-salt-1kg', 'Iodized crystal salt', 28.00, 'GRC-TAT-082', true, current_timestamp(), current_timestamp()),
('3083', '1018', 'Fortune Sunflower Oil 5L', 'fortune-sunflower-oil-5l', 'Refined cooking oil', 899.00, 'GRC-FOR-083', true, current_timestamp(), current_timestamp()),
('3084', '1018', 'Maggi Noodles Pack', 'maggi-noodles-pack', 'Instant noodles combo', 120.00, 'GRC-MAG-084', true, current_timestamp(), current_timestamp()),
('3085', '1018', 'Amul Butter 500g', 'amul-butter-500g', 'Pasteurized butter', 299.00, 'GRC-AML-085', true, current_timestamp(), current_timestamp()),
('3086', '1018', 'Bru Instant Coffee', 'bru-instant-coffee', 'Instant coffee powder', 399.00, 'GRC-BRU-086', true, current_timestamp(), current_timestamp()),
('3087', '1018', 'Taj Mahal Tea 1kg', 'taj-mahal-tea-1kg', 'Premium tea leaves', 599.00, 'GRC-TAJ-087', true, current_timestamp(), current_timestamp()),
('3088', '1018', 'Parle G Biscuits', 'parle-g-biscuits', 'Glucose biscuits family pack', 60.00, 'GRC-PRL-088', true, current_timestamp(), current_timestamp()),
('3089', '1018', 'Kelloggs Corn Flakes', 'kelloggs-corn-flakes', 'Breakfast cereal', 349.00, 'GRC-KEL-089', true, current_timestamp(), current_timestamp()),
('3090', '1018', 'Basmati Rice 5kg', 'basmati-rice-5kg', 'Premium long grain rice', 699.00, 'GRC-RIC-090', true, current_timestamp(), current_timestamp()),

('3091', '1001', 'Canon PIXMA Printer', 'canon-pixma-printer', 'Wireless inkjet printer', 6499.00, 'ELC-CAN-091', true, current_timestamp(), current_timestamp()),
('3092', '1001', 'Epson EcoTank L3250', 'epson-ecotank-l3250', 'WiFi ink tank printer', 15999.00, 'ELC-EPS-092', true, current_timestamp(), current_timestamp()),
('3093', '1001', 'TP-Link WiFi Router', 'tp-link-wifi-router', 'Dual band wireless router', 2499.00, 'ELC-TPL-093', true, current_timestamp(), current_timestamp()),
('3094', '1001', 'Samsung 27 Inch Monitor', 'samsung-27-monitor', 'Full HD IPS monitor', 14999.00, 'ELC-SMN-094', true, current_timestamp(), current_timestamp()),
('3095', '1001', 'LG Ultrawide Monitor', 'lg-ultrawide-monitor', '29 inch ultrawide display', 22999.00, 'ELC-LG-095', true, current_timestamp(), current_timestamp()),
('3096', '1001', 'Zebronics Mechanical Keyboard', 'zebronics-mechanical-keyboard', 'RGB gaming keyboard', 2999.00, 'ELC-ZEB-096', true, current_timestamp(), current_timestamp()),
('3097', '1001', 'Ant Esports Gaming Mouse', 'ant-esports-gaming-mouse', 'RGB wired gaming mouse', 999.00, 'ELC-ANT-097', true, current_timestamp(), current_timestamp()),
('3098', '1001', 'WD 1TB External HDD', 'wd-1tb-external-hdd', 'Portable external hard drive', 4599.00, 'ELC-WD-098', true, current_timestamp(), current_timestamp()),
('3099', '1001', 'Seagate SSD 1TB', 'seagate-ssd-1tb', 'Portable SSD storage', 7999.00, 'ELC-SEA-099', true, current_timestamp(), current_timestamp()),
('3100', '1001', 'Apple AirPods Pro', 'apple-airpods-pro', 'Noise cancelling earbuds', 24999.00, 'ELC-APL-100', true, current_timestamp(), current_timestamp());

-- %%
INSERT INTO products VALUES
('3101', '1002', 'Lenovo Legion 5 Pro', 'lenovo-legion-5-pro', 'High performance gaming laptop', 139999.00, 'LAP-LEN-101', true, current_timestamp(), current_timestamp()),
('3102', '1002', 'HP Victus 15', 'hp-victus-15', 'RTX powered gaming laptop', 81999.00, 'LAP-HP-102', true, current_timestamp(), current_timestamp()),
('3103', '1002', 'Dell XPS 13', 'dell-xps-13', 'Premium ultrabook laptop', 129999.00, 'LAP-DEL-103', true, current_timestamp(), current_timestamp()),
('3104', '1002', 'ASUS Vivobook OLED', 'asus-vivobook-oled', 'OLED display productivity laptop', 74999.00, 'LAP-ASUS-104', true, current_timestamp(), current_timestamp()),
('3105', '1002', 'Acer Nitro V', 'acer-nitro-v', 'Mid range gaming laptop', 68999.00, 'LAP-ACE-105', true, current_timestamp(), current_timestamp()),
('3106', '1002', 'Samsung Chromebook Go', 'samsung-chromebook-go', 'Student friendly Chromebook', 29999.00, 'LAP-SAM-106', true, current_timestamp(), current_timestamp()),
('3107', '1002', 'MSI Modern 14', 'msi-modern-14', 'Thin and light office laptop', 57999.00, 'LAP-MSI-107', true, current_timestamp(), current_timestamp()),
('3108', '1002', 'Avita Liber V14', 'avita-liber-v14', 'Affordable daily use laptop', 32999.00, 'LAP-AVI-108', true, current_timestamp(), current_timestamp()),
('3109', '1002', 'Honor MagicBook X16', 'honor-magicbook-x16', 'Large display laptop', 54999.00, 'LAP-HNR-109', true, current_timestamp(), current_timestamp()),
('3110', '1002', 'LG Gram 16', 'lg-gram-16', 'Ultra lightweight premium laptop', 119999.00, 'LAP-LG-110', true, current_timestamp(), current_timestamp()),

('3111', '1003', 'iQOO Neo 10', 'iqoo-neo-10', 'Gaming focused smartphone', 34999.00, 'PHN-IQO-111', true, current_timestamp(), current_timestamp()),
('3112', '1003', 'Samsung Galaxy A56', 'samsung-galaxy-a56', 'Mid range Samsung smartphone', 32999.00, 'PHN-SAM-112', true, current_timestamp(), current_timestamp()),
('3113', '1003', 'Google Pixel 9', 'google-pixel-9', 'AI powered Android phone', 79999.00, 'PHN-GGL-113', true, current_timestamp(), current_timestamp()),
('3114', '1003', 'Realme Narzo 80', 'realme-narzo-80', 'Budget gaming smartphone', 18999.00, 'PHN-RLM-114', true, current_timestamp(), current_timestamp()),
('3115', '1003', 'Lava Blaze Curve', 'lava-blaze-curve', 'Made in India smartphone', 17999.00, 'PHN-LAV-115', true, current_timestamp(), current_timestamp()),
('3116', '1003', 'Tecno Camon 30', 'tecno-camon-30', 'Camera focused smartphone', 20999.00, 'PHN-TEC-116', true, current_timestamp(), current_timestamp()),
('3117', '1003', 'Infinix Zero Ultra', 'infinix-zero-ultra', 'Fast charging smartphone', 27999.00, 'PHN-INF-117', true, current_timestamp(), current_timestamp()),
('3118', '1003', 'Moto G85', 'moto-g85', 'Clean Android experience', 22999.00, 'PHN-MOT-118', true, current_timestamp(), current_timestamp()),
('3119', '1003', 'OnePlus Nord CE 5', 'oneplus-nord-ce-5', 'Affordable OnePlus phone', 25999.00, 'PHN-ONE-119', true, current_timestamp(), current_timestamp()),
('3120', '1003', 'Redmi 14C 5G', 'redmi-14c-5g', 'Entry level 5G smartphone', 11999.00, 'PHN-RDM-120', true, current_timestamp(), current_timestamp()),

('3121', '1001', 'Boat Airdopes 141', 'boat-airdopes-141', 'True wireless earbuds', 1499.00, 'ELC-BOAT-121', true, current_timestamp(), current_timestamp()),
('3122', '1001', 'Realme Buds Air 6', 'realme-buds-air-6', 'ANC wireless earbuds', 3499.00, 'ELC-RLM-122', true, current_timestamp(), current_timestamp()),
('3123', '1001', 'Sony SRS-XB13', 'sony-srs-xb13', 'Portable extra bass speaker', 3999.00, 'ELC-SNY-123', true, current_timestamp(), current_timestamp()),
('3124', '1001', 'Apple Magic Mouse', 'apple-magic-mouse', 'Wireless rechargeable mouse', 7499.00, 'ELC-APL-124', true, current_timestamp(), current_timestamp()),
('3125', '1001', 'Dell Wireless Keyboard', 'dell-wireless-keyboard', 'Compact wireless keyboard', 1799.00, 'ELC-DEL-125', true, current_timestamp(), current_timestamp()),
('3126', '1001', 'Corsair Gaming Headset', 'corsair-gaming-headset', 'RGB gaming headset', 4999.00, 'ELC-COR-126', true, current_timestamp(), current_timestamp()),
('3127', '1001', 'Anker USB C Cable', 'anker-usb-c-cable', 'Fast charging cable', 699.00, 'ELC-ANK-127', true, current_timestamp(), current_timestamp()),
('3128', '1001', 'Mi Smart Band 9', 'mi-smart-band-9', 'Fitness tracking smart band', 2999.00, 'ELC-MI-128', true, current_timestamp(), current_timestamp()),
('3129', '1001', 'Amazon Echo Dot 5', 'amazon-echo-dot-5', 'Smart speaker with Alexa', 5499.00, 'ELC-AMZ-129', true, current_timestamp(), current_timestamp()),
('3130', '1001', 'Google Nest Mini', 'google-nest-mini', 'Voice assistant smart speaker', 4499.00, 'ELC-GGL-130', true, current_timestamp(), current_timestamp()),

('3131', '1007', 'Clean Code', 'clean-code', 'Software craftsmanship guide', 799.00, 'BOK-CC-131', true, current_timestamp(), current_timestamp()),
('3132', '1007', 'The Alchemist', 'the-alchemist', 'Inspirational fiction novel', 299.00, 'BOK-ALC-132', true, current_timestamp(), current_timestamp()),
('3133', '1007', 'Do Epic Shit', 'do-epic-shit', 'Motivational life lessons', 249.00, 'BOK-DES-133', true, current_timestamp(), current_timestamp()),
('3134', '1007', 'Harry Potter Box Set', 'harry-potter-box-set', 'Fantasy fiction collection', 3499.00, 'BOK-HP-134', true, current_timestamp(), current_timestamp()),
('3135', '1007', 'Introduction to Algorithms', 'introduction-to-algorithms', 'Computer science algorithms book', 1299.00, 'BOK-ALG-135', true, current_timestamp(), current_timestamp()),
('3136', '1007', 'Python Crash Course', 'python-crash-course', 'Python programming guide', 699.00, 'BOK-PYT-136', true, current_timestamp(), current_timestamp()),
('3137', '1007', '48 Laws of Power', '48-laws-of-power', 'Strategy and influence book', 599.00, 'BOK-LAW-137', true, current_timestamp(), current_timestamp()),
('3138', '1007', 'The Monk Who Sold His Ferrari', 'monk-who-sold-his-ferrari', 'Self help classic', 349.00, 'BOK-MNK-138', true, current_timestamp(), current_timestamp()),
('3139', '1007', 'C Programming Language', 'c-programming-language', 'Classic C programming book', 599.00, 'BOK-CPR-139', true, current_timestamp(), current_timestamp()),
('3140', '1007', 'DSA Made Easy', 'dsa-made-easy', 'Interview preparation guide', 799.00, 'BOK-DSA-140', true, current_timestamp(), current_timestamp()),

('3141', '1009', 'US Polo Men T-Shirt', 'us-polo-men-tshirt', 'Casual cotton t-shirt', 1299.00, 'MEN-USP-141', true, current_timestamp(), current_timestamp()),
('3142', '1009', 'Arrow Formal Trousers', 'arrow-formal-trousers', 'Office wear trousers', 2199.00, 'MEN-ARR-142', true, current_timestamp(), current_timestamp()),
('3143', '1009', 'Adidas Running Shoes', 'adidas-running-shoes', 'Lightweight running shoes', 4299.00, 'MEN-ADI-143', true, current_timestamp(), current_timestamp()),
('3144', '1009', 'HRX Training Shorts', 'hrx-training-shorts', 'Workout shorts for men', 899.00, 'MEN-HRX-144', true, current_timestamp(), current_timestamp()),
('3145', '1009', 'Tommy Hilfiger Polo', 'tommy-hilfiger-polo', 'Premium polo t-shirt', 3499.00, 'MEN-TOM-145', true, current_timestamp(), current_timestamp()),
('3146', '1010', 'Fabindia Cotton Kurta', 'fabindia-cotton-kurta', 'Traditional cotton kurta', 2499.00, 'WMN-FAB-146', true, current_timestamp(), current_timestamp()),
('3147', '1010', 'Forever 21 Jeans', 'forever-21-jeans', 'Skinny fit jeans', 1999.00, 'WMN-F21-147', true, current_timestamp(), current_timestamp()),
('3148', '1010', 'Skechers Women Shoes', 'skechers-women-shoes', 'Comfort walking shoes', 4999.00, 'WMN-SKE-148', true, current_timestamp(), current_timestamp()),
('3149', '1010', 'Only Casual Jacket', 'only-casual-jacket', 'Stylish winter jacket', 3299.00, 'WMN-ONL-149', true, current_timestamp(), current_timestamp()),
('3150', '1010', 'Womens Handbag Leather', 'womens-handbag-leather', 'Premium tote handbag', 2799.00, 'WMN-HBG-150', true, current_timestamp(), current_timestamp()),

('3151', '1011', 'Bajaj Electric Kettle', 'bajaj-electric-kettle', '1.5 litre electric kettle', 1499.00, 'HM-BAJ-151', true, current_timestamp(), current_timestamp()),
('3152', '1011', 'Wonderchef Cookware Set', 'wonderchef-cookware-set', 'Non stick cookware combo', 3999.00, 'HM-WON-152', true, current_timestamp(), current_timestamp()),
('3153', '1011', 'Kent RO Water Purifier', 'kent-ro-water-purifier', 'RO plus UV purifier', 15999.00, 'HM-KNT-153', true, current_timestamp(), current_timestamp()),
('3154', '1011', 'Butterfly Gas Stove', 'butterfly-gas-stove', '3 burner gas stove', 3499.00, 'HM-BFL-154', true, current_timestamp(), current_timestamp()),
('3155', '1011', 'Cello Dinner Set', 'cello-dinner-set', '32 piece dinnerware set', 2199.00, 'HM-CEL-155', true, current_timestamp(), current_timestamp()),
('3156', '1012', 'Godrej Steel Almirah', 'godrej-steel-almirah', 'Double door wardrobe', 18999.00, 'FUR-GOD-156', true, current_timestamp(), current_timestamp()),
('3157', '1012', 'Sleepyhead Mattress', 'sleepyhead-mattress', 'Orthopedic foam mattress', 11999.00, 'FUR-SLP-157', true, current_timestamp(), current_timestamp()),
('3158', '1012', 'Dining Table 4 Seater', 'dining-table-4-seater', 'Wooden dining set', 22999.00, 'FUR-DIN-158', true, current_timestamp(), current_timestamp()),
('3159', '1012', 'TV Unit Cabinet', 'tv-unit-cabinet', 'Modern entertainment unit', 8999.00, 'FUR-TVU-159', true, current_timestamp(), current_timestamp()),
('3160', '1012', 'Shoe Rack Wooden', 'shoe-rack-wooden', 'Multi layer shoe organizer', 2999.00, 'FUR-SHR-160', true, current_timestamp(), current_timestamp()),

('3161', '1013', 'Nivia Volleyball', 'nivia-volleyball', 'Professional volleyball', 799.00, 'SPT-NIV-161', true, current_timestamp(), current_timestamp()),
('3162', '1013', 'Kookaburra Cricket Gloves', 'kookaburra-cricket-gloves', 'Batting gloves pair', 1499.00, 'SPT-KOO-162', true, current_timestamp(), current_timestamp()),
('3163', '1013', 'Decathlon Skipping Rope', 'decathlon-skipping-rope', 'Fitness skipping rope', 399.00, 'SPT-DEC-163', true, current_timestamp(), current_timestamp()),
('3164', '1014', 'Strauss Push Up Bar', 'strauss-push-up-bar', 'Home workout equipment', 699.00, 'FIT-STR-164', true, current_timestamp(), current_timestamp()),
('3165', '1014', 'Gym Gloves Leather', 'gym-gloves-leather', 'Weight lifting gloves', 599.00, 'FIT-GLV-165', true, current_timestamp(), current_timestamp()),
('3166', '1014', 'Exercise Cycle', 'exercise-cycle', 'Indoor cardio cycle', 16999.00, 'FIT-CYC-166', true, current_timestamp(), current_timestamp()),
('3167', '1014', 'Foam Roller', 'foam-roller', 'Muscle recovery roller', 999.00, 'FIT-FRM-167', true, current_timestamp(), current_timestamp()),
('3168', '1014', 'Smart Weighing Scale', 'smart-weighing-scale', 'Bluetooth body weight scale', 1799.00, 'FIT-SCL-168', true, current_timestamp(), current_timestamp()),
('3169', '1015', 'Biotique Face Pack', 'biotique-face-pack', 'Herbal skincare face pack', 249.00, 'BEA-BIO-169', true, current_timestamp(), current_timestamp()),
('3170', '1015', 'LOreal Hair Serum', 'loreal-hair-serum', 'Smoothening hair serum', 499.00, 'BEA-LOR-170', true, current_timestamp(), current_timestamp()),

('3171', '1015', 'Plum Green Tea Toner', 'plum-green-tea-toner', 'Acne control toner', 399.00, 'BEA-PLM-171', true, current_timestamp(), current_timestamp()),
('3172', '1015', 'Minimalist Vitamin C Serum', 'minimalist-vitamin-c-serum', 'Brightening face serum', 699.00, 'BEA-MIN-172', true, current_timestamp(), current_timestamp()),
('3173', '1016', 'Nerf Blaster Gun', 'nerf-blaster-gun', 'Foam dart blaster toy', 1899.00, 'TOY-NRF-173', true, current_timestamp(), current_timestamp()),
('3174', '1016', 'Kids Kitchen Play Set', 'kids-kitchen-play-set', 'Pretend cooking toy set', 1599.00, 'TOY-KIT-174', true, current_timestamp(), current_timestamp()),
('3175', '1016', 'UNO Playing Cards', 'uno-playing-cards', 'Classic family card game', 199.00, 'TOY-UNO-175', true, current_timestamp(), current_timestamp()),
('3176', '1016', 'Jigsaw Puzzle 1000 Pieces', 'jigsaw-puzzle-1000-pieces', 'Educational puzzle game', 799.00, 'TOY-JIG-176', true, current_timestamp(), current_timestamp()),
('3177', '1017', 'Bike Mobile Holder', 'bike-mobile-holder', 'Handlebar phone mount', 499.00, 'AUT-BMH-177', true, current_timestamp(), current_timestamp()),
('3178', '1017', 'Car Perfume Fresh', 'car-perfume-fresh', 'Long lasting fragrance', 299.00, 'AUT-CPF-178', true, current_timestamp(), current_timestamp()),
('3179', '1017', 'Bosch Car Wiper Set', 'bosch-car-wiper-set', 'All weather wiper blades', 899.00, 'AUT-BOS-179', true, current_timestamp(), current_timestamp()),
('3180', '1017', 'Helmet Lock Cable', 'helmet-lock-cable', 'Security cable for helmets', 349.00, 'AUT-HLC-180', true, current_timestamp(), current_timestamp()),

('3181', '1018', 'Surf Excel Matic 2kg', 'surf-excel-matic-2kg', 'Front load detergent powder', 499.00, 'GRC-SRF-181', true, current_timestamp(), current_timestamp()),
('3182', '1018', 'Good Day Biscuits', 'good-day-biscuits', 'Butter cookies pack', 40.00, 'GRC-GDD-182', true, current_timestamp(), current_timestamp()),
('3183', '1018', 'Kissan Mixed Fruit Jam', 'kissan-mixed-fruit-jam', 'Fruit spread bottle', 199.00, 'GRC-KSN-183', true, current_timestamp(), current_timestamp()),
('3184', '1018', 'Dabur Honey 1kg', 'dabur-honey-1kg', 'Pure natural honey', 399.00, 'GRC-DBR-184', true, current_timestamp(), current_timestamp()),
('3185', '1018', 'Saffola Oats 1kg', 'saffola-oats-1kg', 'Healthy breakfast oats', 249.00, 'GRC-SAF-185', true, current_timestamp(), current_timestamp()),
('3186', '1018', 'Amul Cheese Slices', 'amul-cheese-slices', 'Processed cheese slices', 149.00, 'GRC-CHS-186', true, current_timestamp(), current_timestamp()),
('3187', '1018', 'Bournvita Health Drink', 'bournvita-health-drink', 'Chocolate nutrition drink', 429.00, 'GRC-BRN-187', true, current_timestamp(), current_timestamp()),
('3188', '1018', 'Tropicana Orange Juice', 'tropicana-orange-juice', 'Packaged fruit juice', 139.00, 'GRC-TRP-188', true, current_timestamp(), current_timestamp()),
('3189', '1018', 'Haldirams Bhujia', 'haldirams-bhujia', 'Spicy namkeen snack', 99.00, 'GRC-HAL-189', true, current_timestamp(), current_timestamp()),
('3190', '1018', 'Catch Black Pepper', 'catch-black-pepper', 'Ground black pepper spice', 89.00, 'GRC-CTH-190', true, current_timestamp(), current_timestamp()),

('3191', '1001', 'BenQ GW2780 Monitor', 'benq-gw2780-monitor', '27 inch eye care monitor', 13999.00, 'ELC-BEN-191', true, current_timestamp(), current_timestamp()),
('3192', '1001', 'Acer Nitro Monitor', 'acer-nitro-monitor', 'Gaming monitor 180Hz', 18999.00, 'ELC-ACR-192', true, current_timestamp(), current_timestamp()),
('3193', '1001', 'Razer DeathAdder Mouse', 'razer-deathadder-mouse', 'Ergonomic gaming mouse', 3499.00, 'ELC-RZR-193', true, current_timestamp(), current_timestamp()),
('3194', '1001', 'HyperX Cloud Earbuds', 'hyperx-cloud-earbuds', 'Gaming in ear headset', 2999.00, 'ELC-HYX-194', true, current_timestamp(), current_timestamp()),
('3195', '1001', 'Cooler Master Laptop Stand', 'cooler-master-laptop-stand', 'Adjustable cooling stand', 2499.00, 'ELC-CLM-195', true, current_timestamp(), current_timestamp()),
('3196', '1001', 'Philips Smart Bulb', 'philips-smart-bulb', 'WiFi enabled LED bulb', 1299.00, 'ELC-PHL-196', true, current_timestamp(), current_timestamp()),
('3197', '1001', 'Wipro Smart Plug', 'wipro-smart-plug', 'App controlled smart plug', 999.00, 'ELC-WIP-197', true, current_timestamp(), current_timestamp()),
('3198', '1001', 'Canon DSLR EOS 1500D', 'canon-dslr-eos-1500d', 'Entry level DSLR camera', 42999.00, 'ELC-CAN-198', true, current_timestamp(), current_timestamp()),
('3199', '1001', 'GoPro Hero 13', 'gopro-hero-13', '4K action camera', 38999.00, 'ELC-GOP-199', true, current_timestamp(), current_timestamp()),
('3200', '1001', 'DJI Mini Drone', 'dji-mini-drone', 'Compact aerial camera drone', 59999.00, 'ELC-DJI-200', true, current_timestamp(), current_timestamp());

-- %%
INSERT OVERWRITE inventory VALUES
('4001', '3001', 25, 5, current_timestamp()),
('4002', '3002', 18, 4, current_timestamp()),
('4003', '3003', 12, 3, current_timestamp()),
('4004', '3004', 35, 6, current_timestamp()),
('4005', '3005', 22, 5, current_timestamp()),
('4006', '3006', 14, 3, current_timestamp()),
('4007', '3007', 10, 2, current_timestamp()),
('4008', '3008', 20, 5, current_timestamp()),
('4009', '3009', 28, 6, current_timestamp()),
('4010', '3010', 40, 8, current_timestamp()),

('4011', '3011', 30, 5, current_timestamp()),
('4012', '3012', 18, 4, current_timestamp()),
('4013', '3013', 26, 5, current_timestamp()),
('4014', '3014', 24, 5, current_timestamp()),
('4015', '3015', 55, 10, current_timestamp()),
('4016', '3016', 33, 6, current_timestamp()),
('4017', '3017', 21, 4, current_timestamp()),
('4018', '3018', 19, 4, current_timestamp()),
('4019', '3019', 27, 5, current_timestamp()),
('4020', '3020', 42, 8, current_timestamp()),

('4021', '3021', 85, 15, current_timestamp()),
('4022', '3022', 40, 8, current_timestamp()),
('4023', '3023', 16, 3, current_timestamp()),
('4024', '3024', 60, 12, current_timestamp()),
('4025', '3025', 95, 20, current_timestamp()),
('4026', '3026', 75, 15, current_timestamp()),
('4027', '3027', 48, 10, current_timestamp()),
('4028', '3028', 52, 10, current_timestamp()),
('4029', '3029', 70, 14, current_timestamp()),
('4030', '3030', 120, 25, current_timestamp()),

('4031', '3031', 150, 20, current_timestamp()),
('4032', '3032', 130, 18, current_timestamp()),
('4033', '3033', 95, 15, current_timestamp()),
('4034', '3034', 110, 18, current_timestamp()),
('4035', '3035', 60, 10, current_timestamp()),
('4036', '3036', 45, 8, current_timestamp()),
('4037', '3037', 55, 10, current_timestamp()),
('4038', '3038', 140, 20, current_timestamp()),
('4039', '3039', 125, 18, current_timestamp()),
('4040', '3040', 115, 18, current_timestamp()),

('4041', '3041', 90, 15, current_timestamp()),
('4042', '3042', 80, 14, current_timestamp()),
('4043', '3043', 120, 20, current_timestamp()),
('4044', '3044', 65, 12, current_timestamp()),
('4045', '3045', 75, 14, current_timestamp()),
('4046', '3046', 58, 10, current_timestamp()),
('4047', '3047', 92, 16, current_timestamp()),
('4048', '3048', 44, 8, current_timestamp()),
('4049', '3049', 66, 12, current_timestamp()),
('4050', '3050', 88, 15, current_timestamp()),

('4051', '3051', 70, 12, current_timestamp()),
('4052', '3052', 26, 5, current_timestamp()),
('4053', '3053', 95, 18, current_timestamp()),
('4054', '3054', 36, 7, current_timestamp()),
('4055', '3055', 105, 20, current_timestamp()),
('4056', '3056', 24, 5, current_timestamp()),
('4057', '3057', 32, 6, current_timestamp()),
('4058', '3058', 14, 3, current_timestamp()),
('4059', '3059', 29, 5, current_timestamp()),
('4060', '3060', 54, 10, current_timestamp()),

('4061', '3061', 48, 8, current_timestamp()),
('4062', '3062', 58, 10, current_timestamp()),
('4063', '3063', 74, 12, current_timestamp()),
('4064', '3064', 39, 7, current_timestamp()),
('4065', '3065', 82, 14, current_timestamp()),
('4066', '3066', 18, 4, current_timestamp()),
('4067', '3067', 12, 2, current_timestamp()),
('4068', '3068', 97, 18, current_timestamp()),
('4069', '3069', 135, 22, current_timestamp()),
('4070', '3070', 102, 18, current_timestamp()),

('4071', '3071', 88, 15, current_timestamp()),
('4072', '3072', 98, 16, current_timestamp()),
('4073', '3073', 46, 8, current_timestamp()),
('4074', '3074', 57, 10, current_timestamp()),
('4075', '3075', 63, 10, current_timestamp()),
('4076', '3076', 22, 5, current_timestamp()),
('4077', '3077', 81, 14, current_timestamp()),
('4078', '3078', 50, 9, current_timestamp()),
('4079', '3079', 67, 12, current_timestamp()),
('4080', '3080', 45, 8, current_timestamp()),

('4081', '3081', 180, 30, current_timestamp()),
('4082', '3082', 250, 40, current_timestamp()),
('4083', '3083', 130, 22, current_timestamp()),
('4084', '3084', 220, 35, current_timestamp()),
('4085', '3085', 95, 15, current_timestamp()),
('4086', '3086', 84, 14, current_timestamp()),
('4087', '3087', 72, 12, current_timestamp()),
('4088', '3088', 300, 50, current_timestamp()),
('4089', '3089', 68, 12, current_timestamp()),
('4090', '3090', 90, 15, current_timestamp()),

('4091', '3091', 28, 5, current_timestamp()),
('4092', '3092', 16, 3, current_timestamp()),
('4093', '3093', 74, 12, current_timestamp()),
('4094', '3094', 26, 5, current_timestamp()),
('4095', '3095', 18, 4, current_timestamp()),
('4096', '3096', 58, 10, current_timestamp()),
('4097', '3097', 85, 15, current_timestamp()),
('4098', '3098', 37, 7, current_timestamp()),
('4099', '3099', 24, 5, current_timestamp()),
('4100', '3100', 15, 3, current_timestamp()),
('4101', '3101', 14, 3, current_timestamp()),
('4102', '3102', 20, 4, current_timestamp()),
('4103', '3103', 10, 2, current_timestamp()),
('4104', '3104', 18, 4, current_timestamp()),
('4105', '3105', 22, 5, current_timestamp()),
('4106', '3106', 35, 6, current_timestamp()),
('4107', '3107', 25, 5, current_timestamp()),
('4108', '3108', 30, 6, current_timestamp()),
('4109', '3109', 28, 5, current_timestamp()),
('4110', '3110', 12, 2, current_timestamp()),
('4111', '3111', 25, 5, current_timestamp()),
('4112', '3112', 32, 6, current_timestamp()),
('4113', '3113', 15, 3, current_timestamp()),
('4114', '3114', 40, 8, current_timestamp()),
('4115', '3115', 50, 10, current_timestamp()),
('4116', '3116', 30, 6, current_timestamp()),
('4117', '3117', 22, 4, current_timestamp()),
('4118', '3118', 28, 5, current_timestamp()),
('4119', '3119', 35, 7, current_timestamp()),
('4120', '3120', 60, 12, current_timestamp()),
('4121', '3121', 110, 20, current_timestamp()),
('4122', '3122', 75, 15, current_timestamp()),
('4123', '3123', 45, 8, current_timestamp()),
('4124', '3124', 30, 6, current_timestamp()),
('4125', '3125', 55, 10, current_timestamp()),
('4126', '3126', 40, 8, current_timestamp()),
('4127', '3127', 150, 30, current_timestamp()),
('4128', '3128', 85, 15, current_timestamp()),
('4129', '3129', 60, 12, current_timestamp()),
('4130', '3130', 50, 10, current_timestamp()),
('4131', '3131', 70, 12, current_timestamp()),
('4132', '3132', 120, 20, current_timestamp()),
('4133', '3133', 140, 22, current_timestamp()),
('4134', '3134', 35, 6, current_timestamp()),
('4135', '3135', 40, 8, current_timestamp()),
('4136', '3136', 65, 10, current_timestamp()),
('4137', '3137', 80, 12, current_timestamp()),
('4138', '3138', 95, 15, current_timestamp()),
('4139', '3139', 50, 8, current_timestamp()),
('4140', '3140', 60, 10, current_timestamp()),
('4141', '3141', 85, 15, current_timestamp()),
('4142', '3142', 70, 12, current_timestamp()),
('4143', '3143', 55, 10, current_timestamp()),
('4144', '3144', 110, 20, current_timestamp()),
('4145', '3145', 45, 8, current_timestamp()),
('4146', '3146', 40, 8, current_timestamp()),
('4147', '3147', 75, 12, current_timestamp()),
('4148', '3148', 35, 6, current_timestamp()),
('4149', '3149', 48, 8, current_timestamp()),
('4150', '3150', 52, 10, current_timestamp()),
('4151', '3151', 95, 18, current_timestamp()),
('4152', '3152', 40, 8, current_timestamp()),
('4153', '3153', 18, 4, current_timestamp()),
('4154', '3154', 55, 10, current_timestamp()),
('4155', '3155', 64, 12, current_timestamp()),
('4156', '3156', 15, 3, current_timestamp()),
('4157', '3157', 22, 4, current_timestamp()),
('4158', '3158', 12, 2, current_timestamp()),
('4159', '3159', 20, 4, current_timestamp()),
('4160', '3160', 45, 8, current_timestamp()),
('4161', '3161', 65, 12, current_timestamp()),
('4162', '3162', 50, 10, current_timestamp()),
('4163', '3163', 120, 20, current_timestamp()),
('4164', '3164', 85, 15, current_timestamp()),
('4165', '3165', 90, 15, current_timestamp()),
('4166', '3166', 10, 2, current_timestamp()),
('4167', '3167', 55, 10, current_timestamp()),
('4168', '3168', 42, 8, current_timestamp()),
('4169', '3169', 115, 20, current_timestamp()),
('4170', '3170', 80, 14, current_timestamp()),
('4171', '3171', 95, 16, current_timestamp()),
('4172', '3172', 70, 12, current_timestamp()),
('4173', '3173', 45, 8, current_timestamp()),
('4174', '3174', 38, 7, current_timestamp()),
('4175', '3175', 250, 40, current_timestamp()),
('4176', '3176', 60, 10, current_timestamp()),
('4177', '3177', 140, 25, current_timestamp()),
('4178', '3178', 180, 30, current_timestamp()),
('4179', '3179', 75, 12, current_timestamp()),
('4180', '3180', 110, 20, current_timestamp()),
('4181', '3181', 90, 15, current_timestamp()),
('4182', '3182', 350, 50, current_timestamp()),
('4183', '3183', 85, 15, current_timestamp()),
('4184', '3184', 60, 10, current_timestamp()),
('4185', '3185', 120, 20, current_timestamp()),
('4186', '3186', 130, 22, current_timestamp()),
('4187', '3187', 75, 12, current_timestamp()),
('4188', '3188', 140, 25, current_timestamp()),
('4189', '3189', 200, 30, current_timestamp()),
('4190', '3190', 160, 25, current_timestamp()),
('4191', '3191', 30, 6, current_timestamp()),
('4192', '3192', 25, 5, current_timestamp()),
('4193', '3193', 65, 12, current_timestamp()),
('4194', '3194', 48, 8, current_timestamp()),
('4195', '3195', 35, 6, current_timestamp()),
('4196', '3196', 90, 15, current_timestamp()),
('4197', '3197', 80, 14, current_timestamp()),
('4198', '3198', 15, 3, current_timestamp()),
('4199', '3199', 20, 4, current_timestamp()),
('4200', '3200', 10, 2, current_timestamp());

-- %%
INSERT OVERWRITE orders VALUES
(
    '5001',
    '2002',
    '3001',
    1,
    68999.00,
    68999.00,
    'delivered',
    'Noida, Uttar Pradesh',
    'Noida, Uttar Pradesh',
    current_timestamp(),
    current_timestamp()
),
(
    '5002',
    '2003',
    '3011',
    1,
    79999.00,
    79999.00,
    'processing',
    'Bengaluru, Karnataka',
    'Bengaluru, Karnataka',
    current_timestamp(),
    current_timestamp()
),
(
    '5003',
    '2004',
    '3021',
    2,
    2499.00,
    4998.00,
    'shipped',
    'Mumbai, Maharashtra',
    'Mumbai, Maharashtra',
    current_timestamp(),
    current_timestamp()
),
(
    '5004',
    '2005',
    '3031',
    1,
    499.00,
    499.00,
    'delivered',
    'Pune, Maharashtra',
    'Pune, Maharashtra',
    current_timestamp(),
    current_timestamp()
),
(
    '5005',
    '2006',
    '3052',
    1,
    8499.00,
    8499.00,
    'processing',
    'Hyderabad, Telangana',
    'Hyderabad, Telangana',
    current_timestamp(),
    current_timestamp()
),
(
    '5006',
    '2007',
    '3046',
    2,
    2999.00,
    5998.00,
    'shipped',
    'Chennai, Tamil Nadu',
    'Chennai, Tamil Nadu',
    current_timestamp(),
    current_timestamp()
),
(
    '5007',
    '2008',
    '3061',
    1,
    4999.00,
    4999.00,
    'delivered',
    'Lucknow, Uttar Pradesh',
    'Lucknow, Uttar Pradesh',
    current_timestamp(),
    current_timestamp()
),
(
    '5008',
    '2009',
    '3081',
    3,
    499.00,
    1497.00,
    'processing',
    'Jaipur, Rajasthan',
    'Jaipur, Rajasthan',
    current_timestamp(),
    current_timestamp()
),
(
    '5009',
    '2010',
    '3028',
    1,
    2999.00,
    2999.00,
    'delivered',
    'Ahmedabad, Gujarat',
    'Ahmedabad, Gujarat',
    current_timestamp(),
    current_timestamp()
),
(
    '5010',
    '2011',
    '3044',
    1,
    3299.00,
    3299.00,
    'cancelled',
    'Indore, Madhya Pradesh',
    'Indore, Madhya Pradesh',
    current_timestamp(),
    current_timestamp()
),

(
    '5011',
    '2012',
    '3074',
    1,
    1299.00,
    1299.00,
    'shipped',
    'Patna, Bihar',
    'Patna, Bihar',
    current_timestamp(),
    current_timestamp()
),
(
    '5012',
    '2013',
    '3094',
    1,
    14999.00,
    14999.00,
    'delivered',
    'Delhi, Delhi',
    'Delhi, Delhi',
    current_timestamp(),
    current_timestamp()
),
(
    '5013',
    '2014',
    '3015',
    2,
    21999.00,
    43998.00,
    'processing',
    'Kolkata, West Bengal',
    'Kolkata, West Bengal',
    current_timestamp(),
    current_timestamp()
),
(
    '5014',
    '2015',
    '3055',
    4,
    599.00,
    2396.00,
    'delivered',
    'Nagpur, Maharashtra',
    'Nagpur, Maharashtra',
    current_timestamp(),
    current_timestamp()
),
(
    '5015',
    '2016',
    '3069',
    2,
    299.00,
    598.00,
    'shipped',
    'Surat, Gujarat',
    'Surat, Gujarat',
    current_timestamp(),
    current_timestamp()
),
(
    '5016',
    '2017',
    '3036',
    1,
    899.00,
    899.00,
    'processing',
    'Bhopal, Madhya Pradesh',
    'Bhopal, Madhya Pradesh',
    current_timestamp(),
    current_timestamp()
),
(
    '5017',
    '2018',
    '3100',
    1,
    24999.00,
    24999.00,
    'delivered',
    'Gurugram, Haryana',
    'Gurugram, Haryana',
    current_timestamp(),
    current_timestamp()
),
(
    '5018',
    '2019',
    '3088',
    5,
    60.00,
    300.00,
    'processing',
    'Kanpur, Uttar Pradesh',
    'Kanpur, Uttar Pradesh',
    current_timestamp(),
    current_timestamp()
),
(
    '5019',
    '2020',
    '3041',
    2,
    1799.00,
    3598.00,
    'shipped',
    'Chandigarh, Chandigarh',
    'Chandigarh, Chandigarh',
    current_timestamp(),
    current_timestamp()
),
(
    '5020',
    '2021',
    '3023',
    1,
    27999.00,
    27999.00,
    'delivered',
    'Kochi, Kerala',
    'Kochi, Kerala',
    current_timestamp(),
    current_timestamp()
),

(
    '5021',
    '2022',
    '3071',
    3,
    599.00,
    1797.00,
    'processing',
    'Mysuru, Karnataka',
    'Mysuru, Karnataka',
    current_timestamp(),
    current_timestamp()
),
(
    '5022',
    '2023',
    '3098',
    1,
    4599.00,
    4599.00,
    'delivered',
    'Visakhapatnam, Andhra Pradesh',
    'Visakhapatnam, Andhra Pradesh',
    current_timestamp(),
    current_timestamp()
),
(
    '5023',
    '2024',
    '3018',
    1,
    32999.00,
    32999.00,
    'shipped',
    'Ranchi, Jharkhand',
    'Ranchi, Jharkhand',
    current_timestamp(),
    current_timestamp()
),
(
    '5024',
    '2025',
    '3057',
    1,
    6999.00,
    6999.00,
    'processing',
    'Dehradun, Uttarakhand',
    'Dehradun, Uttarakhand',
    current_timestamp(),
    current_timestamp()
),
(
    '5025',
    '2026',
    '3039',
    2,
    399.00,
    798.00,
    'delivered',
    'Varanasi, Uttar Pradesh',
    'Varanasi, Uttar Pradesh',
    current_timestamp(),
    current_timestamp()
),
(
    '5026',
    '2027',
    '3166',
    1,
    16999.00,
    16999.00,
    'shipped',
    'Raipur, Chhattisgarh',
    'Raipur, Chhattisgarh',
    current_timestamp(),
    current_timestamp()
),
(
    '5027',
    '2028',
    '3083',
    2,
    899.00,
    1798.00,
    'delivered',
    'Thane, Maharashtra',
    'Thane, Maharashtra',
    current_timestamp(),
    current_timestamp()
),
(
    '5028',
    '2029',
    '3048',
    1,
    3599.00,
    3599.00,
    'processing',
    'Nashik, Maharashtra',
    'Nashik, Maharashtra',
    current_timestamp(),
    current_timestamp()
),
(
    '5029',
    '2030',
    '3099',
    1,
    7999.00,
    7999.00,
    'delivered',
    'Faridabad, Haryana',
    'Faridabad, Haryana',
    current_timestamp(),
    current_timestamp()
),
(
    '5030',
    '2031',
    '3079',
    2,
    1499.00,
    2998.00,
    'shipped',
    'Amritsar, Punjab',
    'Amritsar, Punjab',
    current_timestamp(),
    current_timestamp()
);
