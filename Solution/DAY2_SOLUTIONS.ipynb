# %% [markdown]
# #Day 2 Practice Solutions

# %%
# %sql 
USE workspace.ecommerce_sql

# %%
CREATE TABLE student (
  id STRING,
  name STRING,
  age INT,
  enrollment_date DATE
);

# %%
CREATE TABLE student_info (
  id STRING NOT NULL PRIMARY KEY,
  name STRING NOT NULL,
  age INT,
  enrollment_date DATE
);

# %%
INSERT INTO student_info (id, name, age, enrollment_date)
VALUES ('S001', 'Alice', 20, '2026-05-23');

# %%
# %sql
INSERT INTO student_info
VALUES ('S001', 'Alice', 20, '2026-05-23');

# %%
# Insert into with column name With multiple rows
INSERT INTO student_info (id, name, age, enrollment_date)
VALUES 
  ('S002', 'Bob', 22, '2026-05-24'),
  ('S003', 'Charlie', 21, '2026-05-25'),
  ('S004', 'Diana', 23, '2026-05-26');

# %%
# %sql
SELECT * FROM categories;

# %%
# %sql
SELECT id, name
FROM categories;

# %%
# %sql
SELECT name AS category_name
FROM categories;

# %%
# %sql
SELECT slug AS category_slug
FROM categories;

# %%
# %sql
SELECT DISTINCT parent_id
FROM categories;

# %%
# %sql
SELECT *
FROM categories
WHERE name = 'Electronics';

# %%
# %sql
SELECT *
FROM categories
WHERE parent_id IS NULL;

# %%
# %sql
SELECT *
FROM categories
WHERE parent_id IS NOT NULL;

# %%
# %sql
SELECT *
FROM categories
WHERE name LIKE 'M%';

# %%
# %sql
SELECT *
FROM categories
WHERE name LIKE '%s';

# %%
# %sql
SELECT *
FROM categories
WHERE slug LIKE '%phone%';

# %%
# %sql
SELECT *
FROM categories
LIMIT 3;

# %%
# %sql
SELECT *
FROM categories
ORDER BY name ASC;

# %%
# %sql
SELECT *
FROM categories
ORDER BY name DESC;

# %%
# %sql
SELECT id, name, slug
FROM categories;

# %%
# %sql
SELECT *
FROM categories
WHERE name LIKE '_____%';

# %%
# %sql
SELECT *
FROM categories
WHERE name LIKE 'Home%';

# %%
# %sql
SELECT *
FROM categories
WHERE slug RLIKE 'phone';

# %%
# %sql
SELECT *
FROM categories
WHERE name IN ('Electronics', 'Books', 'Fashion');

# %%
# %sql
SELECT *
FROM categories
WHERE name != 'Electronics';

# %%
# %sql
SELECT *
FROM categories
WHERE parent_id IS NOT NULL
AND name LIKE 'S%';

# %%
# %sql
SELECT *
FROM categories
WHERE name LIKE 'B%'
OR slug LIKE '%tech%';

# %%
# %sql
SELECT *
FROM categories
WHERE created_at > '2025-01-01';

# %%
# %sql
SELECT *
FROM categories
WHERE created_at BETWEEN '2025-01-01' AND '2025-12-31';

# %%
# %sql
SELECT *
FROM categories
ORDER BY parent_id NULLS FIRST;

# %%
# %sql
SELECT *
FROM categories
ORDER BY parent_id NULLS LAST;

# %%
# %sql
SELECT *
FROM categories
ORDER BY name, created_at;

# %%
# %sql
SELECT *
FROM categories
LIMIT 2
OFFSET 1;

# %%
# %sql
SELECT CAST(id AS STRING)
FROM categories;

# %%
# %sql
SELECT TRY_CAST(id AS STRING)
FROM categories;

# %%
# %sql
SELECT 
    name,
    slug,
    CONCAT(name, ' - ', slug) AS category_details
FROM categories;

# %%
# %sql
SELECT UPPER(name)
FROM categories;

# %%
# %sql
SELECT LOWER(name)
FROM categories;

# %%
# %sql
SELECT 
    name,
    LENGTH(name) AS name_length
FROM categories;

# %%
# %sql
SELECT 
    description,
    REPLACE(description, 'Sports', 'Running') AS updated_description
FROM categories;

# %%
# %sql
SELECT CURRENT_DATE();

# %%
# %sql
SELECT CURRENT_TIMESTAMP();

# %%
# %sql
SELECT *
FROM categories
WHERE description LIKE '%devices%';

# %%
# %sql
SELECT *
FROM categories
WHERE slug LIKE 'mobile%';

# %%
# %sql
SELECT *
FROM categories
ORDER BY updated_at DESC
LIMIT 3;

# %% [markdown]
# # Beginner Level Questions with Answers
#
# ## Question 1
# Display all columns from the `categories` table.
#
# ### Explanation
# `SELECT *` is used to retrieve all columns and all rows from a table.
#
# ### Answer
# ```sql
# SELECT * FROM categories;
# ```
#
# ---
#
# ## Question 2
# Display only `id` and `name` columns.
#
# ### Explanation
# You can retrieve specific columns by mentioning their names after `SELECT`.
#
# ### Answer
# ```sql
# SELECT id, name
# FROM categories;
# ```
#
# ---
#
# ## Question 3
# Display the `name` column with alias `category_name`.
#
# ### Explanation
# Aliases are temporary names given to columns for better readability.
#
# ### Answer
# ```sql
# SELECT name AS category_name
# FROM categories;
# ```
#
# ---
#
# ## Question 4
# Display the `slug` column with alias `category_slug`.
#
# ### Explanation
# The `AS` keyword is used to rename a column in the output.
#
# ### Answer
# ```sql
# SELECT slug AS category_slug
# FROM categories;
# ```
#
# ---
#
# ## Question 5
# Display all unique `parent_id` values.
#
# ### Explanation
# `DISTINCT` removes duplicate values from the result.
#
# ### Answer
# ```sql
# SELECT DISTINCT parent_id
# FROM categories;
# ```
#
# ---
#
# ## Question 6
# Display all categories where name is `Electronics`.
#
# ### Explanation
# The `WHERE` clause is used to filter rows based on a condition.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE name = 'Electronics';
# ```
#
# ---
#
# ## Question 7
# Display all categories where `parent_id` is NULL.
#
# ### Explanation
# `IS NULL` is used to find missing or empty values.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE parent_id IS NULL;
# ```
#
# ---
#
# ## Question 8
# Display all categories where `parent_id` is NOT NULL.
#
# ### Explanation
# `IS NOT NULL` is used to find rows that contain values.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE parent_id IS NOT NULL;
# ```
#
# ---
#
# ## Question 9
# Display all categories where name starts with `M`.
#
# ### Explanation
# `LIKE 'M%'` checks for values starting with the letter `M`.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE name LIKE 'M%';
# ```
#
# ---
#
# ## Question 10
# Display all categories where name ends with `s`.
#
# ### Explanation
# `LIKE '%s'` checks for values ending with the letter `s`.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE name LIKE '%s';
# ```
#
# ---
#
# ## Question 11
# Display all categories where `slug` contains the word `phone`.
#
# ### Explanation
# `LIKE '%word%'` is used to search for values containing a specific pattern.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE slug LIKE '%phone%';
# ```
#
# ---
#
# ## Question 12
# Display only the first 3 rows from the table.
#
# ### Explanation
# `LIMIT` restricts the number of rows returned.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# LIMIT 3;
# ```
#
# ---
#
# ## Question 13
# Sort all categories by `name` in ascending order.
#
# ### Explanation
# `ORDER BY ASC` sorts data from A to Z.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# ORDER BY name ASC;
# ```
#
# ---
#
# ## Question 14
# Sort all categories by `name` in descending order.
#
# ### Explanation
# `ORDER BY DESC` sorts data from Z to A.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# ORDER BY name DESC;
# ```
#
# ---
#
# ## Question 15
# Display only `id`, `name`, and `slug` columns.
#
# ### Explanation
# Multiple columns can be selected together by separating them with commas.
#
# ### Answer
# ```sql
# SELECT id, name, slug
# FROM categories;
# ```

# %% [markdown]
# # Intermediate Level Questions with Answers
#
# ## Question 16
# Display all categories where name contains exactly 5 characters.
#
# ### Explanation
# The `_` wildcard represents exactly one character in SQL pattern matching.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE name LIKE '_____';
# ```
#
# ---
#
# ## Question 17
# Display all categories where name matches the pattern `Home%`.
#
# ### Explanation
# `%` represents zero or more characters after the word `Home`.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE name LIKE 'Home%';
# ```
#
# ---
#
# ## Question 18
# Display all categories where `slug` matches a regex pattern.
#
# ### Explanation
# `RLIKE` is used for regular expression pattern matching.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE slug RLIKE 'phone';
# ```
#
# ---
#
# ## Question 19
# Display all categories where name is either `Electronics`, `Books`, or `Fashion`.
#
# ### Explanation
# The `IN` operator checks multiple values in a single condition.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE name IN ('Electronics', 'Books', 'Fashion');
# ```
#
# ---
#
# ## Question 20
# Display all categories where name is NOT `Electronics`.
#
# ### Explanation
# `!=` is used to exclude specific values.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE name != 'Electronics';
# ```
#
# ---
#
# ## Question 21
# Display all categories where `parent_id` is NOT NULL and name starts with `S`.
#
# ### Explanation
# `AND` combines multiple conditions that must all be true.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE parent_id IS NOT NULL
# AND name LIKE 'S%';
# ```
#
# ---
#
# ## Question 22
# Display all categories where name starts with `B` OR slug contains `tech`.
#
# ### Explanation
# `OR` returns rows when at least one condition is true.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE name LIKE 'B%'
# OR slug LIKE '%tech%';
# ```
#
# ---
#
# ## Question 23
# Display all categories created after `2025-01-01`.
#
# ### Explanation
# Comparison operators can be used with date and timestamp columns.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE created_at > '2025-01-01';
# ```
#
# ---
#
# ## Question 24
# Display all categories created between `2025-01-01` and `2025-12-31`.
#
# ### Explanation
# `BETWEEN` checks whether a value falls within a range.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE created_at BETWEEN '2025-01-01' AND '2025-12-31';
# ```
#
# ---
#
# ## Question 25
# Sort categories by `parent_id` using NULLS FIRST.
#
# ### Explanation
# `NULLS FIRST` displays NULL values before non-NULL values.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# ORDER BY parent_id NULLS FIRST;
# ```
#
# ---
#
# ## Question 26
# Sort categories by `parent_id` using NULLS LAST.
#
# ### Explanation
# `NULLS LAST` displays NULL values after non-NULL values.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# ORDER BY parent_id NULLS LAST;
# ```
#
# ---
#
# ## Question 27
# Sort categories first by `name` and then by `created_at`.
#
# ### Explanation
# Multiple columns can be used together in `ORDER BY`.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# ORDER BY name, created_at;
# ```
#
# ---
#
# ## Question 28
# Display 2 rows after skipping the first 1 row.
#
# ### Explanation
# `OFFSET` skips rows before returning the result set.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# LIMIT 2
# OFFSET 1;
# ```

# %% [markdown]
# # Advanced Level Questions with Answers
#
# ## Question 29
# Convert the `id` column into STRING datatype.
#
# ### Explanation
# `CAST()` is used to convert one datatype into another datatype.
#
# ### Answer
# ```sql
# SELECT CAST(id AS STRING)
# FROM categories;
# ```
#
# ---
#
# ## Question 30
# Try converting the `id` column using safe casting.
#
# ### Explanation
# `TRY_CAST()` returns NULL instead of showing an error if conversion fails.
#
# ### Answer
# ```sql
# SELECT TRY_CAST(id AS STRING)
# FROM categories;
# ```
#
# ---
#
# ## Question 31
# Create a computed column by combining `name` and `slug`.
#
# ### Explanation
# Computed columns are created dynamically using expressions and operators.
#
# ### Answer
# ```sql
# SELECT
#     name,
#     slug,
#     CONCAT(name, ' - ', slug) AS category_details
# FROM categories;
# ```
#
# ---
#
# ## Question 32
# Display category names in uppercase.
#
# ### Explanation
# `UPPER()` converts text into uppercase letters.
#
# ### Answer
# ```sql
# SELECT UPPER(name)
# FROM categories;
# ```
#
# ---
#
# ## Question 33
# Display category names in lowercase.
#
# ### Explanation
# `LOWER()` converts text into lowercase letters.
#
# ### Answer
# ```sql
# SELECT LOWER(name)
# FROM categories;
# ```
#
# ---
#
# ## Question 34
# Find the length of each category name.
#
# ### Explanation
# `LENGTH()` returns the number of characters in a string.
#
# ### Answer
# ```sql
# SELECT
#     name,
#     LENGTH(name) AS name_length
# FROM categories;
# ```
#
# ---
#
# ## Question 35
# Replace the word `Sports` with `Running` in description.
#
# ### Explanation
# `REPLACE()` substitutes one text value with another.
#
# ### Answer
# ```sql
# SELECT
#     description,
#     REPLACE(description, 'Sports', 'Running') AS updated_description
# FROM categories;
# ```
#
# ---
#
# ## Question 36
# Display the current date.
#
# ### Explanation
# `CURRENT_DATE()` returns the system’s current date.
#
# ### Answer
# ```sql
# SELECT CURRENT_DATE();
# ```
#
# ---
#
# ## Question 37
# Display the current timestamp.
#
# ### Explanation
# `CURRENT_TIMESTAMP()` returns the current date and time.
#
# ### Answer
# ```sql
# SELECT CURRENT_TIMESTAMP();
# ```
#
# ---
#
# ## Question 38
# Display categories where description contains the word `devices`.
#
# ### Explanation
# `LIKE` can also be used on long text columns for searching patterns.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE description LIKE '%devices%';
# ```
#
# ---
#
# ## Question 39
# Display categories where `slug` starts with `mobile`.
#
# ### Explanation
# `LIKE 'text%'` checks values starting with a specific word.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# WHERE slug LIKE 'mobile%';
# ```
#
# ---
#
# ## Question 40
# Display the latest 3 updated categories.
#
# ### Explanation
# `ORDER BY DESC` with `LIMIT` is commonly used to fetch recent records.
#
# ### Answer
# ```sql
# SELECT *
# FROM categories
# ORDER BY updated_at DESC
# LIMIT 3;
# ```
